# %%
import textdescriptives as td
import pandas as pd

# %%
lista = list()

with open("dataset/txt_user_story/g02-federalspending.txt") as file:
    for line in file:
        lista.append(line)

df = pd.DataFrame(data=lista, columns=["txt"])
df
# Out:
#                                                   txt
# 0   ï»¿As a Data user, I want to have the 12-19-20...
# 1   As a UI designer, I want to redesign the Resou...
# 2   As a UI designer, I want to report to the Agen...
# 3   As a UI designer, I want to move on to round 2...
# 4   As a UI designer, I want to move on to round 2...
# ..                                                ...
# 93  As a FABS user, I want to have my validations ...
# 94  As a FABS user, I want to see correct status l...
# 95  As an agency user, I want to know when the sub...
# 96  As an agency user, I want a landing page to na...
# 97  As an agency user, I want to submit my data el...
#
# [98 rows x 1 columns]

# %%
def calcular_gunning_fog(texto):
    df = td.extract_metrics(text=texto, spacy_model="en_core_web_sm", metrics=["readability"])
    return df["gunning_fog"].iloc[0]

# %%
df["GF"] = df["txt"].apply(calcular_gunning_fog)

# %%
df
# Out:
#                                                   txt         GF
# 0   ï»¿As a Data user, I want to have the 12-19-20...   8.666667
# 1   As a UI designer, I want to redesign the Resou...  10.304762
# 2   As a UI designer, I want to report to the Agen...  14.358621
# 3   As a UI designer, I want to move on to round 2...  14.057143
# 4   As a UI designer, I want to move on to round 2...  12.933333
# ..                                                ...        ...
# 93  As a FABS user, I want to have my validations ...  11.644444
# 94  As a FABS user, I want to see correct status l...  13.200000
# 95  As an agency user, I want to know when the sub...  13.476923
# 96  As an agency user, I want a landing page to na...  12.628571
# 97  As an agency user, I want to submit my data el...  13.200000
#
# [98 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
X = df["GF"]
plt.hist(x = X)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Projetos\USER_STORY\main.ipynb Cell 6 line 3
#       <a href='vscode-notebook-cell:/c%3A/Projetos/USER_STORY/main.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/c%3A/Projetos/USER_STORY/main.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> X = df["GF"]
# ----> <a href='vscode-notebook-cell:/c%3A/Projetos/USER_STORY/main.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> plt.hist(x = X)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\pyplot.py:2561, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2555 @_copy_docstring_and_deprecators(Axes.hist)
#    2556 def hist(
#    2557         x, bins=None, range=None, density=False, weights=None,
#    2558         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2559         orientation='vertical', rwidth=None, log=False, color=None,
#    2560         label=None, stacked=False, *, data=None, **kwargs):
# -> 2561     return gca().hist(
#    2562         x, bins=bins, range=range, density=density, weights=weights,
#    2563         cumulative=cumulative, bottom=bottom, histtype=histtype,
#    2564         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2565         color=color, label=label, stacked=stacked,
#    2566         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~\AppData\Roaming\Python\Python310\site-packages\matplotlib\axes\_axes.py:6677, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6673 for xi in x:
#    6674     if len(xi):
#    6675         # python's min/max ignore nan,
#    6676         # np.minnan returns nan for all nan input
# -> 6677         xmin = min(xmin, np.nanmin(xi))
#    6678         xmax = max(xmax, np.nanmax(xi))
#    6679 if xmin <= xmax:  # Only happens if we have seen a finite value.
#
# TypeError: '<' not supported between instances of '_iLocIndexer' and 'float'

# %%
X.describe()
# Out:
# count    98.000000
# mean     11.943488
# std       3.010925
# min       5.200000
# 25%      10.000000
# 50%      12.245503
# 75%      13.903509
# max      18.571429
# Name: GF, dtype: float64

# %%
X.describe()["50%"]
# Out:
# 12.245502645502647
